# %%
import pandas as pd

coffee = pd.Series([3500, 4000, 2500, 5000], \
                   index=["아메리카노", "라떼", "하우스커피", "마끼아또"])
print(coffee)
# Out:
# 아메리카노    3500
# 라떼       4000
# 하우스커피    2500
# 마끼아또     5000
# dtype: int64

# %%
coffee.index
# Out:
# Index(['아메리카노', '라떼', '하우스커피', '마끼아또'], dtype='object')

# %%
coffee.values
# Out:
# array([3500, 4000, 2500, 5000])

# %%
coffee = pd.Series({'아메리카노':3500, '라떼':4000, '하우스커피':2500, '마끼아또':5000})
coffee
# Out:
# 아메리카노    3500
# 라떼       4000
# 하우스커피    2500
# 마끼아또     5000
# dtype: int64

# %%
values = [[15, 0, 3000], [25, 1, 2500], [35, 0, 4500]]
columns = ['age', 'male', 'income']

df = pd.DataFrame(values, columns=columns)
print(df)
# Out:
#    age  male  income
# 0   15     0    3000
# 1   25     1    2500
# 2   35     0    4500

# %%
values = [[15, 0, 3000], [25, 1, 2500], [35, 0, 4500]]
columns = ['age', 'male', 'income']

df = pd.DataFrame(values, columns=columns)
df.to_csv('test.csv') #csv 파일 포멧으로 데이터프레임 저장
df = pd.read_csv('test.csv') #csv 파일 읽어서 데이터프레임 로드
print(df)
# Out:
#    Unnamed: 0  age  male  income
# 0           0   15     0    3000
# 1           1   25     1    2500
# 2           2   35     0    4500

# %%
housing = pd.read_csv("sample_data/california_housing_test.csv",\
                          index_col=0, parse_dates=True)
housing.head() #처음 다섯개 행 데이터
# Out:
#            latitude  housing_median_age  total_rooms  total_bedrooms  \
# longitude
# -122.05       37.37                27.0       3885.0           661.0
# -118.30       34.26                43.0       1510.0           310.0
# -117.81       33.78                27.0       3589.0           507.0
# -118.36       33.82                28.0         67.0            15.0
# -119.67       36.33                19.0       1241.0           244.0
#
#            population  households  median_income  median_house_value
# longitude
# -122.05        1537.0       606.0         6.6085            344700.0
# -118.30         809.0       277.0         3.5990            176500.0
# -117.81        1484.0       495.0         5.7934            270500.0
# -118.36          49.0        11.0         6.1359            330000.0
# -119.67         850.0       237.0         2.9375             81700.0

# %%
lat_age = housing[['latitude', 'housing_median_age']]
lat_age
# Out:
#            latitude  housing_median_age
# longitude
# -122.05       37.37                27.0
# -118.30       34.26                43.0
# -117.81       33.78                27.0
# -118.36       33.82                28.0
# -119.67       36.33                19.0
# ...             ...                 ...
# -119.86       34.42                23.0
# -118.14       34.06                27.0
# -119.70       36.30                10.0
# -117.12       34.10                40.0
# -119.63       34.42                42.0
#
# [3000 rows x 2 columns]

# %%
lat_age.shape
# Out:
# (3000, 2)

# %%
type(lat_age)
# Out:
# pandas.core.frame.DataFrame

# %%
housing.plot.scatter(x='latitude', y='housing_median_age', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='housing_median_age'>

# %%
housing["add_col"] = housing["housing_median_age"] * 3
housing.head()
# Out:
#            latitude  housing_median_age  total_rooms  total_bedrooms  \
# longitude
# -122.05       37.37                27.0       3885.0           661.0
# -118.30       34.26                43.0       1510.0           310.0
# -117.81       33.78                27.0       3589.0           507.0
# -118.36       33.82                28.0         67.0            15.0
# -119.67       36.33                19.0       1241.0           244.0
#
#            population  households  median_income  median_house_value  add_col
# longitude
# -122.05        1537.0       606.0         6.6085            344700.0     81.0
# -118.30         809.0       277.0         3.5990            176500.0    129.0
# -117.81        1484.0       495.0         5.7934            270500.0     81.0
# -118.36          49.0        11.0         6.1359            330000.0     84.0
# -119.67         850.0       237.0         2.9375             81700.0     57.0
